# %% [markdown]
# # WFAS Gridded Fire Danger Processor

# %%
import xarray as xr

# %%
fn = 'Data/rtma-2023-05-17T00%3A00%3A00Z.nc'
ds = xr.open_dataset(fn)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 24, lon: 2345, lat: 1597)
# Coordinates:
#   * time                 (time) datetime64[ns] 2023-05-17 ... 2023-05-17T23:0...
#   * lon                  (lon) float32 -138.4 -138.3 -138.3 ... -59.07 -59.04
#   * lat                  (lat) float32 19.35 19.37 19.39 ... 57.18 57.2 57.23
# Data variables:
#     Relative_humidity    (time, lat, lon) float32 ...
#     Solar_radiation      (time, lat, lon) float32 ...
#     Temperature          (time, lat, lon) float32 ...
#     Total_precipitation  (time, lat, lon) float32 ...
#     Wind_direction       (time, lat, lon) float32 ...
#     Wind_speed           (time, lat, lon) float32 ...
# Attributes:
#     CDI:                       Climate Data Interface version 1.9.6 (http://m...
#     Conventions:               CF-1.6
#     history:                   merged all timesteps
#     spatial_ref:               GEOGCS["WGS 84", \n DATUM["World Geodetic Syst...
# ...
